# %% [markdown]
# # Gaze and Pose-Based Interaction
#
# Work by Antonio Vila Leis and Enric Baixauli Casañ

# %%
import os
import zipfile
import glob
import random
import matplotlib.pyplot as plt
from PIL import Image

# %%
file_path = '/dataset'
image_paths = glob.glob(os.path.join(file_path, '**/*.jpg'), recursive=True)
print(f"Total images found in the dataset: {len(image_paths)}")
